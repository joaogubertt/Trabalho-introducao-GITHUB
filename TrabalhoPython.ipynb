# %% [markdown]
# <a href="https://colab.research.google.com/github/joaogubertt/TrabalhoPython/blob/main/TrabalhoPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 #importacao da lib OpenCv(visao computacional)
import numpy as np #importacao da lib NumPy(matematica, calculos)
from google.colab.patches import cv2_imshow #importar a imagem para o codigo

#contraste e brilho
img_in = cv2.imread('data/t1.jpg',0) #aqui é chamada a imagem
a = -1
b = 1

img_out = a*img_in + b # aqui é a saida da imagem

img_out = np.array(img_out, dtype = np.uint8) # aqui é a saida da imagem modificada

cv2_imshow(img_in) 
cv2_imshow(img_out)
'''
cv2.imshow('in', img_in)
cv2.waitKey(0)
cv2.imshow('out', img_out)
cv2.waitKey(0)
cv2.destroyAllWindows()
'''

# o codigo faz alteracoes removendo o brilho e o contraste, alterando a imagem original
# para uma nova, onde podemos destacar novos padroes e analises que na imagem original
# nao poderiam ser vistos, o contraste é similar ao brilho, mas regula os tons de branco.


# Autores
# Guilherme Montenegro de Oliveira
# Joao Pedro Gubertt
# Out:
# <PIL.Image.Image image mode=L size=500x250 at 0x7FBDF2CFDB10>
# <PIL.Image.Image image mode=L size=500x250 at 0x7FBDF2CFDC10>
# "\ncv2.imshow('in', img_in)\ncv2.waitKey(0)\ncv2.imshow('out', img_out)\ncv2.waitKey(0)\ncv2.destroyAllWindows()\n"
